# %%
import pandas as pd H Hello, what Shravani paid insurance already now. So today, bucket twice and payments. Thirty lakhs investment based on Kunna, rainy season complete production, beautiful challenges, struggles they face challenges ten days. This is one of the most popular and relevant professional certificates offered on Coursera, and there is a reason over three million students are signing up to learn data analytics. This program again is completely beginner-friendly, and instructors at Google are going to teach you everything you need to know to get started with a career in data analytics. Data is everywhere, and it can be overwhelming if you don't know how to ask the right questions and how to prepare the data for platform under normal kitchen platform. kitchen platform superheat all of a sudden Idolans love you too, lobby to. having, saving, love you, so love you, love your love you love you love you love you love you love your dialing extra seven point six centimeter female can receive one five centimeter

print("Pandas installed successfully!")
# Out:
# Running cells with 'Python 3.14.4' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/sravani/AppData/Roaming/uv/python/cpython-3.14.4-windows-x86_64-none/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
df.isnull().sum()

# %%
df.info()

# %%
import pandas as pd

df = pd.read_csv("../data/your_dataset.csv")
df.head()
# Out:
# Running cells with 'cpython-3.14.4-windows-x86_64-none (3.14.4) (Python 3.14.4)' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/sravani/AppData/Roaming/uv/python/cpython-3.14.4-windows-x86_64-none/python.exe -m pip install ipykernel -U --force-reinstall'
