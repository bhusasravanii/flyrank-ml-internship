# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/bhusasravanii/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
# My Lane as an ML Task

My project is **ClaimWatch AI**, an insurance fraud detection system.

**ML Task Type:** Classification

The goal of the model is to predict whether an insurance claim is **fraudulent** or **genuine** based on customer, policy, and claim information.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
# Target or Proxy

**Target Column:** fraud_reported

The target column contains:
- **1** → Fraudulent Claim
- **0** → Genuine Claim

The model learns from historical insurance claims and predicts whether a new claim is likely to be fraudulent.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
# Success Metric

Primary Metric:
- F1 Score

Other Metrics:
- Precision
- Recall
- Accuracy

F1 Score is the most important metric because fraud datasets are usually imbalanced. It balances precision and recall to measure how well the model detects fraud while reducing false alarms.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
1. My lane as an ML task (Markdown)
   ↓
[Markdown cell]

2. Target or Proxy (Markdown)
   ↓
[Markdown cell]

3. Success Metric (Markdown)
   ↓
[Markdown cell]

4. The unit of analysis, as a real dataframe
   ↓
[Code cell]   ← ✅ Put Step 4 code here
   ↓
[Markdown cell] ← Explain "One row = one insurance claim"

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
